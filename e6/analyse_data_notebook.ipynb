# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
data_file = 'data.csv'

# %%
data = pd.read_csv(data_file)
melt = pd.melt(data)
posthoc = pairwise_tukeyhsd(melt['value'], melt['variable'], alpha=0.05)

# %%
print(posthoc)
# Out:
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================
#     group1         group2     meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------
#          merge partition_sort   -0.092  0.001 -0.1566 -0.0274   True
#          merge            qs1  -0.1608  0.001 -0.2254 -0.0961   True
#          merge            qs2  -0.1225  0.001 -0.1871 -0.0579   True
#          merge            qs3  -0.1288  0.001 -0.1934 -0.0642   True
#          merge            qs4   0.6701  0.001  0.6055  0.7348   True
#          merge            qs5   0.1721  0.001  0.1075  0.2367   True
# partition_sort            qs1  -0.0688 0.0287 -0.1334 -0.0041   True
# partition_sort            qs2  -0.0305 0.7742 -0.0951  0.0341  False
# partition_sort            qs3  -0.0368 0.6058 -0.1014  0.0278  False
# partition_sort            qs4   0.7621  0.001  0.6975  0.8267   True
# partition_sort            qs5   0.2641  0.001  0.1995  0.3287   True
#            qs1            qs2   0.0382 0.5667 -0.0264  0.1029  False
#            qs1            qs3    0.032 0.7352 -0.0327  0.0966  False
#            qs1            qs4   0.8309  0.001  0.7663  0.8955   True
#            qs1            qs5   0.3329  0.001  0.2682  0.3975   True
#            qs2            qs3  -0.0063    0.9 -0.0709  0.0583  False
#            qs2            qs4   0.7926  0.001   0.728  0.8573   True
#            qs2            qs5   0.2946  0.001    0.23  0.3593   True
#            qs3            qs4   0.7989  0.001  0.7343  0.8635   True
#            qs3            qs5   0.3009  0.001  0.2363  0.3655   True
#            qs4            qs5   -0.498  0.001 -0.5626 -0.4334   True
# --------------------------------------------------------------------

# %%
posthoc.plot_simultaneous()
